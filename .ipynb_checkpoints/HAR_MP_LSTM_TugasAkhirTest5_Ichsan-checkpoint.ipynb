# %%
# !pip install tensorflow opencv-python mediapipe sklearn matplotlib pydot

# %%
import cv2 # OpenCV
import numpy as np
import os # For manipulating directory
from matplotlib import pyplot as plt
import time
import mediapipe as mp
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential # Sequential model
from tensorflow.keras.layers import LSTM, Dense # Layers name
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score
import seaborn as sns # Matrics visualization
import itertools

# %%
mp_pose = mp.solutions.pose # Pose model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities
mp_connections = mp.solutions.pose_connections # Pose Connections

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # Convert BGR to RGB
    image.flags.writeable = False # Image is unwritable
    results = model.process(image) # Prediction
    image.flags.writeable = True # Image is writeable
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # Convert RGB to BGR
    return image, results

def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image,
                              results.pose_landmarks,
                              mp_pose.POSE_CONNECTIONS)
    
def draw_styled_landmarks(image, results):
    mp_drawing.draw_landmarks(image,
                              results.pose_landmarks,
                              mp_pose.POSE_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(80,110,10),
                                                     thickness=1,
                                                     circle_radius=1),
                              mp_drawing.DrawingSpec(color=(80,255,121),
                                                     thickness=1,
                                                     circle_radius=1))
    
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.y, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(4*33)
    return pose

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title="Confusion matrix",
                          cmap=plt.cm.Blues):
    """
    Prints & plots confusion matrix.
    Normalization can be applied by setting "normalize=True".
    """
    plt.imshow(cm, interpolation="nearest", cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    if normalize:
        cm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print("Confusion matrix, without normalization")
        
    print(cm)
    
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
        
    plt.tight_layout()
    plt.ylabel("True label")
    plt.xlabel("Predicted label")

# %%
# Path for exporting data in numpy array format
DATA_PATH = os.path.join("MP_DATA_3")

# Action to detect
actions = np.array(["walk", "run", "jump", "gallop sideways", "bend", "one-hand wave", "two-hands wave", "jump in place", "jumping jack", "skip"])

# Data role
roles = np.array(["train", "test"])

# 9 videos per action
#no_sequences = 9

# 6 videos per action for training
no_sequences_train = 18

# 3 videos per action for testing
no_sequences_test = 6

# frame length
sequence_length = 25

# %%
# Make folder for saving landmarks/keypoints data

for role in roles:
    if role == "train":
        for action in actions:
            for sequence_train in range(no_sequences_train):
                try:
                    os.makedirs(os.path.join(DATA_PATH, role, action, str(sequence_train)))
                except:
                    pass
    else:
        for action in actions:
            for sequence_test in range(no_sequences_test):
                try:
                    os.makedirs(os.path.join(DATA_PATH, role, action, str(sequence_test)))
                except:
                    pass

# %%
# Play video input simultaneously & try to collect keypoints values
# train & test folder
# This is used

with mp_pose.Pose(static_image_mode=False,
                  model_complexity=1,
                  smooth_landmarks=True,
                  enable_segmentation=False,
                  smooth_segmentation=True,
                  min_detection_confidence=0.5,
                  min_tracking_confidence=0.5) as pose:   
    for role in roles:
        if role == "train":
            for action in actions:
                for sequence_train in range(no_sequences_train):
                    cap = cv2.VideoCapture("dataset_traintest_augmented/{}/{}/{}.avi".format(role, action, sequence_train))
                    for frame_num in range(sequence_length):
                        # Read feed
                        ret, frame = cap.read()
                        # Make detections
                        image, results = mediapipe_detection(frame, pose)
                        print(results)
                        # Draw landmarks
                        draw_styled_landmarks(image, results)
                        # Export keypoints
                        keypoints = extract_keypoints(results)
                        npy_path = os.path.join(DATA_PATH, role, action, str(sequence_train), str(frame_num))
                        np.save(npy_path, keypoints)
                        # Show to screen
                        cv2.imshow("OpenCV Feed", image)
                        # Break while loop
                        if cv2.waitKey(10) & 0xFF == ord("q"):
                            break
                    cap.release()
                cv2.destroyAllWindows()
        else:
            for action in actions:
                for sequence_test in range(no_sequences_test):
                    cap = cv2.VideoCapture("dataset_traintest_augmented/{}/{}/{}.avi".format(role, action, sequence_test))
                    for frame_num in range(sequence_length):
                        # Read feed
                        ret, frame = cap.read()
                        # Make detections
                        image, results = mediapipe_detection(frame, pose)
                        print(results)
                        # Draw landmarks
                        draw_styled_landmarks(image, results)
                        # Export keypoints
                        keypoints = extract_keypoints(results)
                        npy_path = os.path.join(DATA_PATH, role, action, str(sequence_test), str(frame_num))
                        np.save(npy_path, keypoints)
                        # Show to screen
                        cv2.imshow("OpenCV Feed", image)
                        # Break while loop
                        if cv2.waitKey(10) & 0xFF == ord("q"):
                            break
                    cap.release()
                cv2.destroyAllWindows()

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'walk': 0,
#  'run': 1,
#  'jump': 2,
#  'gallop sideways': 3,
#  'bend': 4,
#  'one-hand wave': 5,
#  'two-hands wave': 6,
#  'jump in place': 7,
#  'jumping jack': 8,
#  'skip': 9}

# %%
# Labelling each sequence/class
sequences_train, labels_train = [], []
sequences_test, labels_test = [], []

for role in roles:
    if role == "train":
        for action in actions:
            for sequence_train in range(no_sequences_train):
                window = []
                for frame_num in range(sequence_length):
                    res = np.load(os.path.join(DATA_PATH, role, action, str(sequence_train), "{}.npy".format(frame_num)))
                    window.append(res)
                sequences_train.append(window)
                labels_train.append(label_map[action])
    else:
        for action in actions:
            for sequence_test in range(no_sequences_test):
                window = []
                for frame_num in range(sequence_length):
                    res = np.load(os.path.join(DATA_PATH, role, action, str(sequence_test), "{}.npy".format(frame_num)))
                    window.append(res)
                sequences_test.append(window)
                labels_test.append(label_map[action])

# %%
X_train = np.array(sequences_train)
X_test = np.array(sequences_test)

y_train = to_categorical(labels_train).astype(int)
y_test = to_categorical(labels_test).astype(int)

# %%
print("X_train shape : "+str(X_train.shape))
print("X_test shape : "+str(X_test.shape))
print("y_train shape : "+str(y_train.shape))
print("y_test shape : "+str(y_test.shape))
# Out:
# X_train shape : (180, 25, 132)
# X_test shape : (60, 25, 132)
# y_train shape : (180, 10)
# y_test shape : (60, 10)

# %%
# Auto split training/testing data
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
# Locate log folder for monitoring
log_dir = os.path.join("Logs")
tb_callback = TensorBoard(log_dir=log_dir)

# %%
# Define a sequential model that consists of LSTM and Dense layers
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation="relu", input_shape=(25,132)))
model.add(LSTM(128, return_sequences=True, activation="relu"))
model.add(LSTM(64, return_sequences=False, activation="relu"))
model.add(Dense(64, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(actions.shape[0], activation="softmax"))

# %%
# Define a sequential model - another format
model = Sequential([
    LSTM(64, return_sequences=True, activation="relu", input_shape=(25,132)),
    LSTM(128, return_sequences=True, activation="relu"),
    LSTM(64, return_sequences=False, activation="relu"),
    Dense(64, activation="relu"),
    Dense(32, activation="relu"),
    Dense(actions.shape[0], activation="softmax")
])

# %%
# Compile the model above
#model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["categorical_accuracy"])

# %%
# Compile model with learning rate
model.compile(Adam(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["categorical_accuracy"])

# %%
# Training model with auto validation split
history = model.fit(X_train, y_train, batch_size=5, epochs=200, shuffle=False, verbose=2,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/200
# 36/36 - 6s - loss: 2.3411 - categorical_accuracy: 0.1000 - val_loss: 2.2986 - val_categorical_accuracy: 0.1000 - 6s/epoch - 162ms/step
# Epoch 2/200
# 36/36 - 1s - loss: 2.3044 - categorical_accuracy: 0.1000 - val_loss: 2.2953 - val_categorical_accuracy: 0.1000 - 1s/epoch - 39ms/step
# Epoch 3/200
# 36/36 - 1s - loss: 2.3027 - categorical_accuracy: 0.1000 - val_loss: 2.2913 - val_categorical_accuracy: 0.2000 - 1s/epoch - 37ms/step
# Epoch 4/200
# 36/36 - 1s - loss: 2.2998 - categorical_accuracy: 0.1278 - val_loss: 2.2834 - val_categorical_accuracy: 0.1833 - 1s/epoch - 37ms/step
# Epoch 5/200
# 36/36 - 1s - loss: 2.2943 - categorical_accuracy: 0.1722 - val_loss: 2.2737 - val_categorical_accuracy: 0.2000 - 1s/epoch - 37ms/step
# Epoch 6/200
# 36/36 - 1s - loss: 2.2792 - categorical_accuracy: 0.1556 - val_loss: 2.2540 - val_categorical_accuracy: 0.1167 - 1s/epoch - 37ms/step
# Epoch 7/200
# 36/36 - 1s - loss: 2.2868 - categorical_accuracy: 0.0500 - val_loss: 2.2149 - val_categorical_accuracy: 0.1833 - 1s/epoch - 40ms/step
# Epoch 8/200
# 36/36 - 1s - loss: 2.1287 - categorical_accuracy: 0.1056 - val_loss: 9.9686 - val_categorical_accuracy: 0.1000 - 1s/epoch - 40ms/step
# Epoch 9/200
# 36/36 - 1s - loss: 2.2529 - categorical_accuracy: 0.1611 - val_loss: 2.1152 - val_categorical_accuracy: 0.1333 - 1s/epoch - 39ms/step
# Epoch 10/200
# 36/36 - 1s - loss: 2.1974 - categorical_accuracy: 0.0333 - val_loss: 2.0591 - val_categorical_accuracy: 0.2333 - 1s/epoch - 40ms/step
# Epoch 11/200
# 36/36 - 1s - loss: 2.0525 - categorical_accuracy: 0.2444 - val_loss: 2.0315 - val_categorical_accuracy: 0.2000 - 1s/epoch - 37ms/step
# Epoch 12/200
# 36/36 - 1s - loss: 2.0835 - categorical_accuracy: 0.2056 - val_loss: 2.2056 - val_categorical_accuracy: 0.2000 - 1s/epoch - 37ms/step
# Epoch 13/200
# 36/36 - 1s - loss: 2.1810 - categorical_accuracy: 0.1000 - val_loss: 1.9869 - val_categorical_accuracy: 0.2000 - 1s/epoch - 37ms/step
# Epoch 14/200
# 36/36 - 1s - loss: 2.0107 - categorical_accuracy: 0.2444 - val_loss: 1.9707 - val_categorical_accuracy: 0.1833 - 1s/epoch - 36ms/step
# Epoch 15/200
# 36/36 - 1s - loss: 2.0792 - categorical_accuracy: 0.2000 - val_loss: 1.9857 - val_categorical_accuracy: 0.2667 - 1s/epoch - 36ms/step
# Epoch 16/200
# 36/36 - 1s - loss: 2.1816 - categorical_accuracy: 0.1389 - val_loss: 2.0878 - val_categorical_accuracy: 0.2000 - 1s/epoch - 39ms/step
# Epoch 17/200
# 36/36 - 1s - loss: 2.0966 - categorical_accuracy: 0.2222 - val_loss: 1.9760 - val_categorical_accuracy: 0.2833 - 1s/epoch - 38ms/step
# Epoch 18/200
# 36/36 - 1s - loss: 1.9643 - categorical_accuracy: 0.2833 - val_loss: 1.8537 - val_categorical_accuracy: 0.2000 - 1s/epoch - 37ms/step
# Epoch 19/200
# 36/36 - 1s - loss: 1.9191 - categorical_accuracy: 0.2167 - val_loss: 1.8437 - val_categorical_accuracy: 0.2667 - 1s/epoch - 40ms/step
# Epoch 20/200
# 36/36 - 1s - loss: 1.9185 - categorical_accuracy: 0.2667 - val_loss: 1.8183 - val_categorical_accuracy: 0.2667 - 1s/epoch - 37ms/step
# Epoch 21/200
# 36/36 - 1s - loss: 1.8924 - categorical_accuracy: 0.2778 - val_loss: 1.7837 - val_categorical_accuracy: 0.2333 - 1s/epoch - 37ms/step
# Epoch 22/200
# 36/36 - 1s - loss: 1.8808 - categorical_accuracy: 0.2944 - val_loss: 1.7660 - val_categorical_accuracy: 0.2667 - 1s/epoch - 39ms/step
# Epoch 23/200
# 36/36 - 1s - loss: 1.9177 - categorical_accuracy: 0.3167 - val_loss: 1.9498 - val_categorical_accuracy: 0.2667 - 1s/epoch - 37ms/step
# Epoch 24/200
# 36/36 - 1s - loss: 1.9874 - categorical_accuracy: 0.1889 - val_loss: 1.8121 - val_categorical_accuracy: 0.2500 - 1s/epoch - 37ms/step
# Epoch 25/200
# 36/36 - 1s - loss: 1.8724 - categorical_accuracy: 0.3056 - val_loss: 1.7470 - val_categorical_accuracy: 0.2833 - 1s/epoch - 36ms/step
# Epoch 26/200
# 36/36 - 1s - loss: 1.7799 - categorical_accuracy: 0.3167 - val_loss: 1.5824 - val_categorical_accuracy: 0.3500 - 1s/epoch - 37ms/step
# Epoch 27/200
# 36/36 - 1s - loss: 1.7946 - categorical_accuracy: 0.3278 - val_loss: 1.8079 - val_categorical_accuracy: 0.2667 - 1s/epoch - 37ms/step
# Epoch 28/200
# 36/36 - 1s - loss: 1.6863 - categorical_accuracy: 0.2611 - val_loss: 1.7466 - val_categorical_accuracy: 0.2667 - 1s/epoch - 37ms/step
# Epoch 29/200
# 36/36 - 1s - loss: 1.6349 - categorical_accuracy: 0.3222 - val_loss: 1.5212 - val_categorical_accuracy: 0.3500 - 1s/epoch - 37ms/step
# Epoch 30/200
# 36/36 - 1s - loss: 1.5707 - categorical_accuracy: 0.3333 - val_loss: 1.4093 - val_categorical_accuracy: 0.4500 - 1s/epoch - 36ms/step
# Epoch 31/200
# 36/36 - 1s - loss: 1.5647 - categorical_accuracy: 0.3611 - val_loss: 1.5306 - val_categorical_accuracy: 0.4000 - 1s/epoch - 36ms/step
# Epoch 32/200
# 36/36 - 1s - loss: 1.6826 - categorical_accuracy: 0.3056 - val_loss: 1.3007 - val_categorical_accuracy: 0.4833 - 1s/epoch - 37ms/step
# Epoch 33/200
# 36/36 - 1s - loss: 1.6256 - categorical_accuracy: 0.3556 - val_loss: 1.7445 - val_categorical_accuracy: 0.2500 - 1s/epoch - 36ms/step
# Epoch 34/200
# 36/36 - 1s - loss: 1.5458 - categorical_accuracy: 0.3222 - val_loss: 1.4792 - val_categorical_accuracy: 0.2667 - 1s/epoch - 37ms/step
# Epoch 35/200
# 36/36 - 2s - loss: 1.3907 - categorical_accuracy: 0.4056 - val_loss: 1.4213 - val_categorical_accuracy: 0.2667 - 2s/epoch - 42ms/step
# Epoch 36/200
# 36/36 - 1s - loss: 1.3088 - categorical_accuracy: 0.3778 - val_loss: 1.1352 - val_categorical_accuracy: 0.5167 - 1s/epoch - 41ms/step
# Epoch 37/200
# 36/36 - 1s - loss: 1.3516 - categorical_accuracy: 0.3333 - val_loss: 1.2377 - val_categorical_accuracy: 0.5000 - 1s/epoch - 40ms/step
# Epoch 38/200
# 36/36 - 1s - loss: 1.1777 - categorical_accuracy: 0.4611 - val_loss: 1.0001 - val_categorical_accuracy: 0.6333 - 1s/epoch - 38ms/step
# Epoch 39/200
# 36/36 - 2s - loss: 1.3140 - categorical_accuracy: 0.3167 - val_loss: 1.4545 - val_categorical_accuracy: 0.3833 - 2s/epoch - 42ms/step
# Epoch 40/200
# 36/36 - 1s - loss: 1.2490 - categorical_accuracy: 0.4444 - val_loss: 1.5184 - val_categorical_accuracy: 0.3333 - 1s/epoch - 39ms/step
# Epoch 41/200
# 36/36 - 2s - loss: 1.1936 - categorical_accuracy: 0.4778 - val_loss: 1.5919 - val_categorical_accuracy: 0.2833 - 2s/epoch - 43ms/step
# Epoch 42/200
# 36/36 - 1s - loss: 1.1033 - categorical_accuracy: 0.5167 - val_loss: 1.1397 - val_categorical_accuracy: 0.4833 - 1s/epoch - 37ms/step
# Epoch 43/200
# 36/36 - 1s - loss: 1.1214 - categorical_accuracy: 0.4611 - val_loss: 1.0569 - val_categorical_accuracy: 0.5833 - 1s/epoch - 38ms/step
# Epoch 44/200
# 36/36 - 1s - loss: 1.1856 - categorical_accuracy: 0.3833 - val_loss: 1.4143 - val_categorical_accuracy: 0.4833 - 1s/epoch - 41ms/step
# Epoch 45/200
# 36/36 - 2s - loss: 1.1993 - categorical_accuracy: 0.4667 - val_loss: 1.9563 - val_categorical_accuracy: 0.3333 - 2s/epoch - 46ms/step
# Epoch 46/200
# 36/36 - 1s - loss: 1.1961 - categorical_accuracy: 0.5000 - val_loss: 1.4840 - val_categorical_accuracy: 0.4667 - 1s/epoch - 40ms/step
# Epoch 47/200
# 36/36 - 1s - loss: 1.1716 - categorical_accuracy: 0.4556 - val_loss: 1.6389 - val_categorical_accuracy: 0.4000 - 1s/epoch - 37ms/step
# Epoch 48/200
# 36/36 - 1s - loss: 1.1823 - categorical_accuracy: 0.4278 - val_loss: 1.4586 - val_categorical_accuracy: 0.4000 - 1s/epoch - 40ms/step
# Epoch 49/200
# 36/36 - 2s - loss: 1.1541 - categorical_accuracy: 0.4833 - val_loss: 1.3691 - val_categorical_accuracy: 0.4333 - 2s/epoch - 42ms/step
# Epoch 50/200
# 36/36 - 1s - loss: 1.1807 - categorical_accuracy: 0.4556 - val_loss: 1.0558 - val_categorical_accuracy: 0.5167 - 1s/epoch - 36ms/step
# Epoch 51/200
# 36/36 - 1s - loss: 1.1775 - categorical_accuracy: 0.4278 - val_loss: 0.9738 - val_categorical_accuracy: 0.5833 - 1s/epoch - 36ms/step
# Epoch 52/200
# 36/36 - 1s - loss: 1.0024 - categorical_accuracy: 0.5167 - val_loss: 1.0201 - val_categorical_accuracy: 0.6333 - 1s/epoch - 37ms/step
# Epoch 53/200
# 36/36 - 1s - loss: 1.0466 - categorical_accuracy: 0.4444 - val_loss: 1.3514 - val_categorical_accuracy: 0.6000 - 1s/epoch - 41ms/step
# Epoch 54/200
# 36/36 - 1s - loss: 1.2823 - categorical_accuracy: 0.3944 - val_loss: 1.0746 - val_categorical_accuracy: 0.4833 - 1s/epoch - 40ms/step
# Epoch 55/200
# 36/36 - 1s - loss: 0.9681 - categorical_accuracy: 0.5889 - val_loss: 0.9374 - val_categorical_accuracy: 0.5167 - 1s/epoch - 39ms/step
# Epoch 56/200
# 36/36 - 1s - loss: 0.9809 - categorical_accuracy: 0.5222 - val_loss: 0.9431 - val_categorical_accuracy: 0.5833 - 1s/epoch - 39ms/step
# Epoch 57/200
# 36/36 - 1s - loss: 0.9123 - categorical_accuracy: 0.5222 - val_loss: 0.9202 - val_categorical_accuracy: 0.5500 - 1s/epoch - 38ms/step
# Epoch 58/200
# 36/36 - 1s - loss: 0.9009 - categorical_accuracy: 0.5556 - val_loss: 0.8981 - val_categorical_accuracy: 0.6500 - 1s/epoch - 38ms/step
# Epoch 59/200
# 36/36 - 1s - loss: 0.8380 - categorical_accuracy: 0.5556 - val_loss: 0.8977 - val_categorical_accuracy: 0.5667 - 1s/epoch - 38ms/step
# Epoch 60/200
# 36/36 - 1s - loss: 0.8658 - categorical_accuracy: 0.5278 - val_loss: 1.0615 - val_categorical_accuracy: 0.5333 - 1s/epoch - 41ms/step
# Epoch 61/200
# 36/36 - 1s - loss: 0.8024 - categorical_accuracy: 0.6278 - val_loss: 1.1977 - val_categorical_accuracy: 0.4833 - 1s/epoch - 37ms/step
# Epoch 62/200
# 36/36 - 1s - loss: 0.9053 - categorical_accuracy: 0.5111 - val_loss: 1.1806 - val_categorical_accuracy: 0.4000 - 1s/epoch - 38ms/step
# Epoch 63/200
# 36/36 - 1s - loss: 0.8227 - categorical_accuracy: 0.6500 - val_loss: 1.1232 - val_categorical_accuracy: 0.5167 - 1s/epoch - 39ms/step
# Epoch 64/200
# 36/36 - 1s - loss: 0.8197 - categorical_accuracy: 0.6111 - val_loss: 1.0328 - val_categorical_accuracy: 0.5333 - 1s/epoch - 41ms/step
# Epoch 65/200
# 36/36 - 1s - loss: 0.8862 - categorical_accuracy: 0.4944 - val_loss: 1.1578 - val_categorical_accuracy: 0.4667 - 1s/epoch - 38ms/step
# Epoch 66/200
# 36/36 - 1s - loss: 0.9299 - categorical_accuracy: 0.5944 - val_loss: 1.0818 - val_categorical_accuracy: 0.5333 - 1s/epoch - 38ms/step
# Epoch 67/200
# 36/36 - 1s - loss: 0.8397 - categorical_accuracy: 0.6000 - val_loss: 1.0002 - val_categorical_accuracy: 0.4500 - 1s/epoch - 39ms/step
# Epoch 68/200
# 36/36 - 2s - loss: 0.7577 - categorical_accuracy: 0.6167 - val_loss: 1.0009 - val_categorical_accuracy: 0.5000 - 2s/epoch - 45ms/step
# Epoch 69/200
# 36/36 - 1s - loss: 0.7938 - categorical_accuracy: 0.5333 - val_loss: 0.8959 - val_categorical_accuracy: 0.6333 - 1s/epoch - 38ms/step
# Epoch 70/200
# 36/36 - 1s - loss: 0.8220 - categorical_accuracy: 0.5500 - val_loss: 1.2143 - val_categorical_accuracy: 0.4500 - 1s/epoch - 40ms/step
# Epoch 71/200
# 36/36 - 1s - loss: 0.8567 - categorical_accuracy: 0.5778 - val_loss: 0.9714 - val_categorical_accuracy: 0.5333 - 1s/epoch - 38ms/step
# Epoch 72/200
# 36/36 - 1s - loss: 0.8401 - categorical_accuracy: 0.5833 - val_loss: 1.1207 - val_categorical_accuracy: 0.4833 - 1s/epoch - 42ms/step
# Epoch 73/200
# 36/36 - 1s - loss: 0.7893 - categorical_accuracy: 0.6500 - val_loss: 1.0186 - val_categorical_accuracy: 0.4500 - 1s/epoch - 39ms/step
# Epoch 74/200
# 36/36 - 1s - loss: 0.7898 - categorical_accuracy: 0.5389 - val_loss: 0.9358 - val_categorical_accuracy: 0.5833 - 1s/epoch - 37ms/step
# Epoch 75/200
# 36/36 - 1s - loss: 0.7332 - categorical_accuracy: 0.6722 - val_loss: 0.7766 - val_categorical_accuracy: 0.7500 - 1s/epoch - 37ms/step
# Epoch 76/200
# 36/36 - 1s - loss: 0.7886 - categorical_accuracy: 0.6000 - val_loss: 0.9363 - val_categorical_accuracy: 0.7000 - 1s/epoch - 37ms/step
# Epoch 77/200
# 36/36 - 1s - loss: 0.8385 - categorical_accuracy: 0.6222 - val_loss: 0.8870 - val_categorical_accuracy: 0.7167 - 1s/epoch - 40ms/step
# Epoch 78/200
# 36/36 - 2s - loss: 0.6189 - categorical_accuracy: 0.7389 - val_loss: 0.9091 - val_categorical_accuracy: 0.6500 - 2s/epoch - 44ms/step
# Epoch 79/200
# 36/36 - 1s - loss: 0.8764 - categorical_accuracy: 0.5333 - val_loss: 1.1068 - val_categorical_accuracy: 0.5167 - 1s/epoch - 39ms/step
# Epoch 80/200
# 36/36 - 1s - loss: 0.8622 - categorical_accuracy: 0.5333 - val_loss: 0.9030 - val_categorical_accuracy: 0.6333 - 1s/epoch - 37ms/step
# Epoch 81/200
# 36/36 - 1s - loss: 0.7668 - categorical_accuracy: 0.6167 - val_loss: 0.8055 - val_categorical_accuracy: 0.7000 - 1s/epoch - 40ms/step
# Epoch 82/200
# 36/36 - 1s - loss: 0.7639 - categorical_accuracy: 0.5833 - val_loss: 1.1049 - val_categorical_accuracy: 0.5167 - 1s/epoch - 41ms/step
# Epoch 83/200
# 36/36 - 1s - loss: 0.7933 - categorical_accuracy: 0.6222 - val_loss: 1.0501 - val_categorical_accuracy: 0.4167 - 1s/epoch - 40ms/step
# Epoch 84/200
# 36/36 - 1s - loss: 0.7784 - categorical_accuracy: 0.7111 - val_loss: 0.8600 - val_categorical_accuracy: 0.7167 - 1s/epoch - 39ms/step
# Epoch 85/200
# 36/36 - 1s - loss: 0.7665 - categorical_accuracy: 0.6056 - val_loss: 0.8950 - val_categorical_accuracy: 0.5167 - 1s/epoch - 38ms/step
# Epoch 86/200
# 36/36 - 1s - loss: 0.6576 - categorical_accuracy: 0.6944 - val_loss: 1.0110 - val_categorical_accuracy: 0.5333 - 1s/epoch - 39ms/step
# Epoch 87/200
# 36/36 - 1s - loss: 0.7030 - categorical_accuracy: 0.6944 - val_loss: 0.9070 - val_categorical_accuracy: 0.5333 - 1s/epoch - 38ms/step
# Epoch 88/200
# 36/36 - 1s - loss: 0.7437 - categorical_accuracy: 0.6056 - val_loss: 0.9169 - val_categorical_accuracy: 0.6667 - 1s/epoch - 41ms/step
# Epoch 89/200
# 36/36 - 1s - loss: 0.7361 - categorical_accuracy: 0.6778 - val_loss: 1.1936 - val_categorical_accuracy: 0.5333 - 1s/epoch - 39ms/step
# Epoch 90/200
# 36/36 - 1s - loss: 0.8115 - categorical_accuracy: 0.6278 - val_loss: 0.7810 - val_categorical_accuracy: 0.7000 - 1s/epoch - 39ms/step
# Epoch 91/200
# 36/36 - 1s - loss: 0.6075 - categorical_accuracy: 0.6889 - val_loss: 0.8152 - val_categorical_accuracy: 0.7167 - 1s/epoch - 38ms/step
# Epoch 92/200
# 36/36 - 1s - loss: 0.5626 - categorical_accuracy: 0.7500 - val_loss: 0.7414 - val_categorical_accuracy: 0.6833 - 1s/epoch - 40ms/step
# Epoch 93/200
# 36/36 - 1s - loss: 0.6176 - categorical_accuracy: 0.7333 - val_loss: 0.9551 - val_categorical_accuracy: 0.6667 - 1s/epoch - 38ms/step
# Epoch 94/200
# 36/36 - 1s - loss: 0.6933 - categorical_accuracy: 0.6944 - val_loss: 1.0124 - val_categorical_accuracy: 0.5667 - 1s/epoch - 39ms/step
# Epoch 95/200
# 36/36 - 1s - loss: 0.5434 - categorical_accuracy: 0.8278 - val_loss: 1.1025 - val_categorical_accuracy: 0.5000 - 1s/epoch - 39ms/step
# Epoch 96/200
# 36/36 - 1s - loss: 0.6305 - categorical_accuracy: 0.7222 - val_loss: 1.0680 - val_categorical_accuracy: 0.5167 - 1s/epoch - 40ms/step
# Epoch 97/200
# 36/36 - 1s - loss: 0.8304 - categorical_accuracy: 0.6000 - val_loss: 0.8964 - val_categorical_accuracy: 0.7000 - 1s/epoch - 36ms/step
# Epoch 98/200
# 36/36 - 1s - loss: 0.7269 - categorical_accuracy: 0.6444 - val_loss: 0.8752 - val_categorical_accuracy: 0.5667 - 1s/epoch - 37ms/step
# Epoch 99/200
# 36/36 - 1s - loss: 0.6542 - categorical_accuracy: 0.7611 - val_loss: 0.8744 - val_categorical_accuracy: 0.6833 - 1s/epoch - 40ms/step
# Epoch 100/200
# 36/36 - 1s - loss: 0.5052 - categorical_accuracy: 0.7833 - val_loss: 1.0190 - val_categorical_accuracy: 0.5167 - 1s/epoch - 38ms/step
# Epoch 101/200
# 36/36 - 1s - loss: 0.6853 - categorical_accuracy: 0.6389 - val_loss: 0.9482 - val_categorical_accuracy: 0.5000 - 1s/epoch - 39ms/step
# Epoch 102/200
# 36/36 - 1s - loss: 0.9974 - categorical_accuracy: 0.6500 - val_loss: 1.1923 - val_categorical_accuracy: 0.5833 - 1s/epoch - 39ms/step
# Epoch 103/200
# 36/36 - 1s - loss: 0.7333 - categorical_accuracy: 0.7000 - val_loss: 1.0297 - val_categorical_accuracy: 0.5667 - 1s/epoch - 37ms/step
# Epoch 104/200
# 36/36 - 1s - loss: 0.6774 - categorical_accuracy: 0.7278 - val_loss: 0.8935 - val_categorical_accuracy: 0.6333 - 1s/epoch - 39ms/step
# Epoch 105/200
# 36/36 - 1s - loss: 0.5894 - categorical_accuracy: 0.7278 - val_loss: 0.8119 - val_categorical_accuracy: 0.7167 - 1s/epoch - 39ms/step
# Epoch 106/200
# 36/36 - 1s - loss: 0.5648 - categorical_accuracy: 0.7056 - val_loss: 0.8429 - val_categorical_accuracy: 0.6667 - 1s/epoch - 38ms/step
# Epoch 107/200
# 36/36 - 1s - loss: 0.5479 - categorical_accuracy: 0.7389 - val_loss: 0.7364 - val_categorical_accuracy: 0.7500 - 1s/epoch - 38ms/step
# Epoch 108/200
# 36/36 - 1s - loss: 0.4856 - categorical_accuracy: 0.7667 - val_loss: 0.8087 - val_categorical_accuracy: 0.7333 - 1s/epoch - 38ms/step
# Epoch 109/200
# 36/36 - 2s - loss: 0.3768 - categorical_accuracy: 0.8278 - val_loss: 0.9674 - val_categorical_accuracy: 0.6667 - 2s/epoch - 45ms/step
# Epoch 110/200
# 36/36 - 1s - loss: 0.4714 - categorical_accuracy: 0.7611 - val_loss: 0.9386 - val_categorical_accuracy: 0.7000 - 1s/epoch - 40ms/step
# Epoch 111/200
# 36/36 - 2s - loss: 0.3969 - categorical_accuracy: 0.8278 - val_loss: 0.8304 - val_categorical_accuracy: 0.7333 - 2s/epoch - 42ms/step
# Epoch 112/200
# 36/36 - 1s - loss: 0.4533 - categorical_accuracy: 0.8222 - val_loss: 0.8621 - val_categorical_accuracy: 0.7833 - 1s/epoch - 38ms/step
# Epoch 113/200
# 36/36 - 1s - loss: 0.4542 - categorical_accuracy: 0.8167 - val_loss: 0.6807 - val_categorical_accuracy: 0.7500 - 1s/epoch - 38ms/step
# Epoch 114/200
# 36/36 - 1s - loss: 0.6508 - categorical_accuracy: 0.7556 - val_loss: 1.5902 - val_categorical_accuracy: 0.5500 - 1s/epoch - 37ms/step
# Epoch 115/200
# 36/36 - 1s - loss: 1.1639 - categorical_accuracy: 0.5944 - val_loss: 1.2911 - val_categorical_accuracy: 0.5000 - 1s/epoch - 37ms/step
# Epoch 116/200
# 36/36 - 1s - loss: 1.1983 - categorical_accuracy: 0.4722 - val_loss: 1.1602 - val_categorical_accuracy: 0.6000 - 1s/epoch - 37ms/step
# Epoch 117/200
# 36/36 - 1s - loss: 0.7185 - categorical_accuracy: 0.7667 - val_loss: 1.0714 - val_categorical_accuracy: 0.6167 - 1s/epoch - 39ms/step
# Epoch 118/200
# 36/36 - 1s - loss: 0.4434 - categorical_accuracy: 0.8722 - val_loss: 1.1285 - val_categorical_accuracy: 0.6333 - 1s/epoch - 39ms/step
# Epoch 119/200
# 36/36 - 1s - loss: 0.3715 - categorical_accuracy: 0.8722 - val_loss: 1.4705 - val_categorical_accuracy: 0.5167 - 1s/epoch - 38ms/step
# Epoch 120/200
# 36/36 - 1s - loss: 0.4909 - categorical_accuracy: 0.7778 - val_loss: 1.6201 - val_categorical_accuracy: 0.5000 - 1s/epoch - 39ms/step
# Epoch 121/200
# 36/36 - 1s - loss: 0.6255 - categorical_accuracy: 0.7167 - val_loss: 0.8576 - val_categorical_accuracy: 0.7000 - 1s/epoch - 38ms/step
# Epoch 122/200
# 36/36 - 1s - loss: 0.3208 - categorical_accuracy: 0.8833 - val_loss: 1.1059 - val_categorical_accuracy: 0.6667 - 1s/epoch - 37ms/step
# Epoch 123/200
# 36/36 - 1s - loss: 0.3653 - categorical_accuracy: 0.8833 - val_loss: 1.1515 - val_categorical_accuracy: 0.6333 - 1s/epoch - 37ms/step
# Epoch 124/200
# 36/36 - 1s - loss: 0.4476 - categorical_accuracy: 0.7889 - val_loss: 1.1930 - val_categorical_accuracy: 0.6000 - 1s/epoch - 38ms/step
# Epoch 125/200
# 36/36 - 1s - loss: 0.6837 - categorical_accuracy: 0.7556 - val_loss: 0.9987 - val_categorical_accuracy: 0.6167 - 1s/epoch - 39ms/step
# Epoch 126/200
# 36/36 - 1s - loss: 0.7142 - categorical_accuracy: 0.6722 - val_loss: 0.7094 - val_categorical_accuracy: 0.7667 - 1s/epoch - 38ms/step
# Epoch 127/200
# 36/36 - 1s - loss: 0.3649 - categorical_accuracy: 0.8889 - val_loss: 0.7508 - val_categorical_accuracy: 0.7500 - 1s/epoch - 38ms/step
# Epoch 128/200
# 36/36 - 1s - loss: 0.3482 - categorical_accuracy: 0.8611 - val_loss: 0.8990 - val_categorical_accuracy: 0.7167 - 1s/epoch - 40ms/step
# Epoch 129/200
# 36/36 - 2s - loss: 0.5283 - categorical_accuracy: 0.7167 - val_loss: 1.0356 - val_categorical_accuracy: 0.6333 - 2s/epoch - 43ms/step
# Epoch 130/200
# 36/36 - 1s - loss: 0.3455 - categorical_accuracy: 0.8556 - val_loss: 0.8001 - val_categorical_accuracy: 0.7500 - 1s/epoch - 38ms/step
# Epoch 131/200
# 36/36 - 1s - loss: 0.3418 - categorical_accuracy: 0.8556 - val_loss: 0.7830 - val_categorical_accuracy: 0.7000 - 1s/epoch - 37ms/step
# Epoch 132/200
# 36/36 - 1s - loss: 0.3022 - categorical_accuracy: 0.8722 - val_loss: 1.0186 - val_categorical_accuracy: 0.7833 - 1s/epoch - 37ms/step
# Epoch 133/200
# 36/36 - 1s - loss: 0.4501 - categorical_accuracy: 0.8222 - val_loss: 0.8182 - val_categorical_accuracy: 0.7333 - 1s/epoch - 38ms/step
# Epoch 134/200
# 36/36 - 1s - loss: 0.5328 - categorical_accuracy: 0.7889 - val_loss: 0.9923 - val_categorical_accuracy: 0.7000 - 1s/epoch - 38ms/step
# Epoch 135/200
# 36/36 - 2s - loss: 0.9509 - categorical_accuracy: 0.7500 - val_loss: 0.8480 - val_categorical_accuracy: 0.5667 - 2s/epoch - 44ms/step
# Epoch 136/200
# 36/36 - 2s - loss: 0.6623 - categorical_accuracy: 0.7167 - val_loss: 0.9046 - val_categorical_accuracy: 0.8167 - 2s/epoch - 47ms/step
# Epoch 137/200
# 36/36 - 2s - loss: 0.5255 - categorical_accuracy: 0.7778 - val_loss: 1.2334 - val_categorical_accuracy: 0.6667 - 2s/epoch - 52ms/step
# Epoch 138/200
# 36/36 - 2s - loss: 0.5887 - categorical_accuracy: 0.7889 - val_loss: 1.0803 - val_categorical_accuracy: 0.5500 - 2s/epoch - 46ms/step
# Epoch 139/200
# 36/36 - 2s - loss: 0.4616 - categorical_accuracy: 0.8222 - val_loss: 0.9174 - val_categorical_accuracy: 0.6667 - 2s/epoch - 44ms/step
# Epoch 140/200
# 36/36 - 2s - loss: 0.3200 - categorical_accuracy: 0.8722 - val_loss: 1.1828 - val_categorical_accuracy: 0.6833 - 2s/epoch - 44ms/step
# Epoch 141/200
# 36/36 - 2s - loss: 0.4603 - categorical_accuracy: 0.8444 - val_loss: 1.3331 - val_categorical_accuracy: 0.5500 - 2s/epoch - 45ms/step
# Epoch 142/200
# 36/36 - 2s - loss: 0.5690 - categorical_accuracy: 0.7722 - val_loss: 0.9735 - val_categorical_accuracy: 0.6833 - 2s/epoch - 44ms/step
# Epoch 143/200
# 36/36 - 2s - loss: 0.3508 - categorical_accuracy: 0.8611 - val_loss: 0.9367 - val_categorical_accuracy: 0.6667 - 2s/epoch - 44ms/step
# Epoch 144/200
# 36/36 - 1s - loss: 0.3238 - categorical_accuracy: 0.8722 - val_loss: 1.3509 - val_categorical_accuracy: 0.7000 - 1s/epoch - 42ms/step
# Epoch 145/200
# 36/36 - 1s - loss: 0.4064 - categorical_accuracy: 0.8056 - val_loss: 0.8413 - val_categorical_accuracy: 0.8000 - 1s/epoch - 37ms/step
# Epoch 146/200
# 36/36 - 1s - loss: 0.3520 - categorical_accuracy: 0.8611 - val_loss: 1.2284 - val_categorical_accuracy: 0.7000 - 1s/epoch - 36ms/step
# Epoch 147/200
# 36/36 - 1s - loss: 0.5025 - categorical_accuracy: 0.7889 - val_loss: 0.7830 - val_categorical_accuracy: 0.8000 - 1s/epoch - 38ms/step
# Epoch 148/200
# 36/36 - 1s - loss: 0.6398 - categorical_accuracy: 0.7333 - val_loss: 2.0087 - val_categorical_accuracy: 0.5500 - 1s/epoch - 38ms/step
# Epoch 149/200
# 36/36 - 1s - loss: 0.4057 - categorical_accuracy: 0.8444 - val_loss: 0.9524 - val_categorical_accuracy: 0.7333 - 1s/epoch - 37ms/step
# Epoch 150/200
# 36/36 - 1s - loss: 0.2196 - categorical_accuracy: 0.9500 - val_loss: 0.9879 - val_categorical_accuracy: 0.8000 - 1s/epoch - 37ms/step
# Epoch 151/200
# 36/36 - 1s - loss: 0.1786 - categorical_accuracy: 0.9278 - val_loss: 1.2695 - val_categorical_accuracy: 0.7167 - 1s/epoch - 38ms/step
# Epoch 152/200
# 36/36 - 1s - loss: 0.2809 - categorical_accuracy: 0.8611 - val_loss: 1.0239 - val_categorical_accuracy: 0.7833 - 1s/epoch - 38ms/step
# Epoch 153/200
# 36/36 - 1s - loss: 0.4214 - categorical_accuracy: 0.8222 - val_loss: 1.3907 - val_categorical_accuracy: 0.6667 - 1s/epoch - 38ms/step
# Epoch 154/200
# 36/36 - 1s - loss: 0.5081 - categorical_accuracy: 0.8000 - val_loss: 0.7778 - val_categorical_accuracy: 0.7167 - 1s/epoch - 38ms/step
# Epoch 155/200
# 36/36 - 1s - loss: 0.2581 - categorical_accuracy: 0.9000 - val_loss: 1.1524 - val_categorical_accuracy: 0.7500 - 1s/epoch - 38ms/step
# Epoch 156/200
# 36/36 - 1s - loss: 0.1896 - categorical_accuracy: 0.9333 - val_loss: 0.8206 - val_categorical_accuracy: 0.7167 - 1s/epoch - 38ms/step
# Epoch 157/200
# 36/36 - 1s - loss: 0.2969 - categorical_accuracy: 0.8889 - val_loss: 1.0335 - val_categorical_accuracy: 0.7000 - 1s/epoch - 38ms/step
# Epoch 158/200
# 36/36 - 1s - loss: 0.3047 - categorical_accuracy: 0.8833 - val_loss: 0.9718 - val_categorical_accuracy: 0.7500 - 1s/epoch - 39ms/step
# Epoch 159/200
# 36/36 - 1s - loss: 0.2858 - categorical_accuracy: 0.8944 - val_loss: 1.1995 - val_categorical_accuracy: 0.6833 - 1s/epoch - 38ms/step
# Epoch 160/200
# 36/36 - 1s - loss: 0.3228 - categorical_accuracy: 0.8444 - val_loss: 0.9514 - val_categorical_accuracy: 0.6667 - 1s/epoch - 40ms/step
# Epoch 161/200
# 36/36 - 2s - loss: 0.4074 - categorical_accuracy: 0.8111 - val_loss: 1.2177 - val_categorical_accuracy: 0.5500 - 2s/epoch - 44ms/step
# Epoch 162/200
# 36/36 - 2s - loss: 0.3971 - categorical_accuracy: 0.8333 - val_loss: 0.8869 - val_categorical_accuracy: 0.6667 - 2s/epoch - 45ms/step
# Epoch 163/200
# 36/36 - 1s - loss: 0.2387 - categorical_accuracy: 0.9111 - val_loss: 1.1412 - val_categorical_accuracy: 0.7833 - 1s/epoch - 41ms/step
# Epoch 164/200
# 36/36 - 1s - loss: 0.1553 - categorical_accuracy: 0.9444 - val_loss: 1.1350 - val_categorical_accuracy: 0.7500 - 1s/epoch - 40ms/step
# Epoch 165/200
# 36/36 - 1s - loss: 0.1677 - categorical_accuracy: 0.9389 - val_loss: 1.3071 - val_categorical_accuracy: 0.7333 - 1s/epoch - 39ms/step
# Epoch 166/200
# 36/36 - 2s - loss: 0.1521 - categorical_accuracy: 0.9444 - val_loss: 1.2276 - val_categorical_accuracy: 0.6833 - 2s/epoch - 43ms/step
# Epoch 167/200
# 36/36 - 2s - loss: 0.1198 - categorical_accuracy: 0.9611 - val_loss: 1.2356 - val_categorical_accuracy: 0.7833 - 2s/epoch - 43ms/step
# Epoch 168/200
# 36/36 - 2s - loss: 0.0805 - categorical_accuracy: 0.9667 - val_loss: 1.2943 - val_categorical_accuracy: 0.7333 - 2s/epoch - 45ms/step
# Epoch 169/200
# 36/36 - 2s - loss: 0.1032 - categorical_accuracy: 0.9611 - val_loss: 1.4028 - val_categorical_accuracy: 0.7500 - 2s/epoch - 52ms/step
# Epoch 170/200
# 36/36 - 2s - loss: 0.0643 - categorical_accuracy: 0.9889 - val_loss: 1.5236 - val_categorical_accuracy: 0.7667 - 2s/epoch - 43ms/step
# Epoch 171/200
# 36/36 - 1s - loss: 0.1379 - categorical_accuracy: 0.9611 - val_loss: 1.1706 - val_categorical_accuracy: 0.7833 - 1s/epoch - 41ms/step
# Epoch 172/200
# 36/36 - 2s - loss: 0.2478 - categorical_accuracy: 0.9000 - val_loss: 0.7617 - val_categorical_accuracy: 0.7667 - 2s/epoch - 47ms/step
# Epoch 173/200
# 36/36 - 2s - loss: 0.4333 - categorical_accuracy: 0.8389 - val_loss: 0.8851 - val_categorical_accuracy: 0.8500 - 2s/epoch - 46ms/step
# Epoch 174/200
# 36/36 - 2s - loss: 0.3711 - categorical_accuracy: 0.8167 - val_loss: 1.4240 - val_categorical_accuracy: 0.6000 - 2s/epoch - 47ms/step
# Epoch 175/200
# 36/36 - 2s - loss: 0.7241 - categorical_accuracy: 0.7444 - val_loss: 1.9155 - val_categorical_accuracy: 0.6000 - 2s/epoch - 47ms/step
# Epoch 176/200
# 36/36 - 2s - loss: 0.5221 - categorical_accuracy: 0.8389 - val_loss: 0.8853 - val_categorical_accuracy: 0.7333 - 2s/epoch - 44ms/step
# Epoch 177/200
# 36/36 - 2s - loss: 0.2710 - categorical_accuracy: 0.9056 - val_loss: 1.1886 - val_categorical_accuracy: 0.7167 - 2s/epoch - 47ms/step
# Epoch 178/200
# 36/36 - 1s - loss: 0.2661 - categorical_accuracy: 0.8944 - val_loss: 1.5840 - val_categorical_accuracy: 0.6000 - 1s/epoch - 39ms/step
# Epoch 179/200
# 36/36 - 1s - loss: 0.1530 - categorical_accuracy: 0.9389 - val_loss: 1.3438 - val_categorical_accuracy: 0.7000 - 1s/epoch - 38ms/step
# Epoch 180/200
# 36/36 - 1s - loss: 0.3363 - categorical_accuracy: 0.8389 - val_loss: 1.2529 - val_categorical_accuracy: 0.7167 - 1s/epoch - 37ms/step
# Epoch 181/200
# 36/36 - 1s - loss: 0.2654 - categorical_accuracy: 0.9167 - val_loss: 1.4443 - val_categorical_accuracy: 0.7500 - 1s/epoch - 37ms/step
# Epoch 182/200
# 36/36 - 2s - loss: 0.1149 - categorical_accuracy: 0.9667 - val_loss: 1.8786 - val_categorical_accuracy: 0.6667 - 2s/epoch - 42ms/step
# Epoch 183/200
# 36/36 - 2s - loss: 0.1359 - categorical_accuracy: 0.9444 - val_loss: 1.2780 - val_categorical_accuracy: 0.7500 - 2s/epoch - 44ms/step
# Epoch 184/200
# 36/36 - 1s - loss: 0.0747 - categorical_accuracy: 0.9722 - val_loss: 1.0807 - val_categorical_accuracy: 0.7333 - 1s/epoch - 39ms/step
# Epoch 185/200
# 36/36 - 2s - loss: 0.0848 - categorical_accuracy: 0.9667 - val_loss: 1.6582 - val_categorical_accuracy: 0.7667 - 2s/epoch - 45ms/step
# Epoch 186/200
# 36/36 - 1s - loss: 0.0497 - categorical_accuracy: 0.9889 - val_loss: 1.6521 - val_categorical_accuracy: 0.7333 - 1s/epoch - 41ms/step
# Epoch 187/200
# 36/36 - 2s - loss: 0.0465 - categorical_accuracy: 0.9889 - val_loss: 1.9113 - val_categorical_accuracy: 0.7333 - 2s/epoch - 42ms/step
# Epoch 188/200
# 36/36 - 1s - loss: 0.0400 - categorical_accuracy: 0.9889 - val_loss: 1.9423 - val_categorical_accuracy: 0.7500 - 1s/epoch - 37ms/step
# Epoch 189/200
# 36/36 - 1s - loss: 0.0343 - categorical_accuracy: 0.9944 - val_loss: 2.2024 - val_categorical_accuracy: 0.7333 - 1s/epoch - 38ms/step
# Epoch 190/200
# 36/36 - 1s - loss: 0.0530 - categorical_accuracy: 0.9778 - val_loss: 2.1009 - val_categorical_accuracy: 0.7333 - 1s/epoch - 38ms/step
# Epoch 191/200
# 36/36 - 1s - loss: 0.5554 - categorical_accuracy: 0.7889 - val_loss: 0.7865 - val_categorical_accuracy: 0.7500 - 1s/epoch - 37ms/step
# Epoch 192/200
# 36/36 - 1s - loss: 0.8056 - categorical_accuracy: 0.7222 - val_loss: 0.8623 - val_categorical_accuracy: 0.7833 - 1s/epoch - 37ms/step
# Epoch 193/200
# 36/36 - 1s - loss: 0.7858 - categorical_accuracy: 0.6667 - val_loss: 1.1929 - val_categorical_accuracy: 0.5000 - 1s/epoch - 38ms/step
# Epoch 194/200
# 36/36 - 1s - loss: 0.6669 - categorical_accuracy: 0.7500 - val_loss: 0.9611 - val_categorical_accuracy: 0.6833 - 1s/epoch - 38ms/step
# Epoch 195/200
# 36/36 - 1s - loss: 0.3611 - categorical_accuracy: 0.8500 - val_loss: 0.8305 - val_categorical_accuracy: 0.7667 - 1s/epoch - 37ms/step
# Epoch 196/200
# 36/36 - 1s - loss: 0.1873 - categorical_accuracy: 0.9389 - val_loss: 0.9603 - val_categorical_accuracy: 0.7333 - 1s/epoch - 39ms/step
# Epoch 197/200
# 36/36 - 1s - loss: 0.1689 - categorical_accuracy: 0.9333 - val_loss: 1.2539 - val_categorical_accuracy: 0.8000 - 1s/epoch - 38ms/step
# Epoch 198/200
# 36/36 - 1s - loss: 0.1295 - categorical_accuracy: 0.9500 - val_loss: 1.3374 - val_categorical_accuracy: 0.6833 - 1s/epoch - 37ms/step
# Epoch 199/200
# 36/36 - 2s - loss: 0.0958 - categorical_accuracy: 0.9611 - val_loss: 1.4752 - val_categorical_accuracy: 0.6667 - 2s/epoch - 43ms/step
# Epoch 200/200
# 36/36 - 2s - loss: 0.0923 - categorical_accuracy: 0.9611 - val_loss: 1.6618 - val_categorical_accuracy: 0.7167 - 2s/epoch - 42ms/step

# %%
# Training model
#model.fit(X_train, y_train, epochs=30, callbacks=[tb_callback])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 25, 64)            50432
#
#  lstm_1 (LSTM)               (None, 25, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 205,226
# Trainable params: 205,226
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Save Model
model.save("HAR_MP_LSTM_1336_23022022.h5")

# %%
# Load Model
model.load_weights("HAR_MP_LSTM_1336_23022022.h5")

# %%
# Visualize
plot_model(model, to_file = "ARC_HAR_MP_LSTM_1336_23022022.png", show_shapes = True)

# %%
# Plot training and validation

loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, "y", label="Training Loss")
plt.plot(epochs, val_loss, "r", label="Validation Loss")
plt.title("Training and Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

acc = history.history["categorical_accuracy"]
val_acc = history.history["val_categorical_accuracy"]
plt.plot(epochs, acc, "y", label="Training Acc")
plt.plot(epochs, val_acc, "r", label="Validation Acc")
plt.title("Training and Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
res = model.predict(X_test)

# %%
yhat = model.predict(X_test)
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[48,  6],
#         [ 0,  6]],
#
#        [[52,  2],
#         [ 4,  2]],
#
#        [[54,  0],
#         [ 3,  3]],
#
#        [[54,  0],
#         [ 2,  4]],
#
#        [[54,  0],
#         [ 2,  4]],
#
#        [[54,  0],
#         [ 2,  4]],
#
#        [[52,  2],
#         [ 0,  6]],
#
#        [[51,  3],
#         [ 0,  6]],
#
#        [[52,  2],
#         [ 2,  4]],
#
#        [[52,  2],
#         [ 2,  4]]], dtype=int64)

# %%
cm_plot_labels = []
plot_confusion_matrix(cm=cm, classes=cm_plot_labels, title="Confusion Matrix")

# %%
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
# Unpractical***
conf_matrix = multilabel_confusion_matrix(ytrue, yhat)
sns.heatmap(conf_matrix, annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8336/2192082539.py in <module>
#       1 conf_matrix = multilabel_confusion_matrix(ytrue, yhat)
# ----> 2 sns.heatmap(conf_matrix, annot=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     538     """
#     539     # Initialize the plotter object
# --> 540     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     541                           annot_kws, cbar, cbar_kws, xticklabels,
#     542                           yticklabels, mask)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     104         else:
#     105             plot_data = np.asarray(data)
# --> 106             data = pd.DataFrame(plot_data)
#     107
#     108         # Validate the mask and convet to DataFrame
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     670                 )
#     671             else:
# --> 672                 mgr = ndarray_to_mgr(
#     673                     data,
#     674                     index,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     302         # by definition an array here
#     303         # the dtypes will be coerced to a single dtype
# --> 304         values = _prep_ndarray(values, copy=copy)
#     305
#     306     if dtype is not None and not is_dtype_equal(values.dtype, dtype):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in _prep_ndarray(values, copy)
#     553         values = values.reshape((values.shape[0], 1))
#     554     elif values.ndim != 2:
# --> 555         raise ValueError(f"Must pass 2-d input. shape={values.shape}")
#     556
#     557     return values
#
# ValueError: Must pass 2-d input. shape=(10, 2, 2)

# %%
_, acc = model.evaluate(X_test, y_test)
print("Accuracy = ", (acc*100), " %")

# %%
accuracy_score(ytrue, yhat)

# %%
# Probability visualisation with live side bar chart

colors = [(237, 17, 17), # walk:0 -> red
          (245, 117, 16), # run:1 -> orange
          (235, 224, 16), # jump:2 -> yellow
          (155, 235, 16), # gallop sideways:3 -> lime green
          (86, 224, 58), # bend:4 -> green
          (30, 227, 132), # one-hand wave:5 -> cyan
          (30, 224, 227), # two-hands wave:6 -> light blue
          (22, 38, 219), # jump in place:7 -> blue
          (170, 22, 219), # jumping jack:8 -> purple
          (219, 22, 104)] # skip:9 -> magenta

def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
    
    return output_frame

# %%
# Demo

# new variable
sequence = []
sentence = []
predictions = []
threshold = 0.3

#cap = cv2.VideoCapture(0) # Webcam
cap = cv2.VideoCapture("demovideo/demovideo-dataset-zoom-flip.mp4") # Demo video

# Set mediapipe model
with mp_pose.Pose(static_image_mode=False,
                  model_complexity=1,
                  smooth_landmarks=True,
                  enable_segmentation=False,
                  smooth_segmentation=True,
                  min_detection_confidence=0.5,
                  min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        
        # Read feed
        ret, frame = cap.read()
        
        # Make detections
        image, results = mediapipe_detection(frame, pose)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-25:]
        
        if len(sequence) == 25:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            # Viz logic
            if np.unique(predictions[-10:])[0] == np.argmax(res):
                if res[np.argmax(res)] > threshold:
                    if len(sentence) > 0:
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])
            if len(sentence) > 1:
                sentence = sentence[-1:]
                
            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (720,40), (245,117,16), -1)
        cv2.putText(image, " ".join(sentence), (3,30),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow("OpenCV Feed", image)
        
        #Break
        if cv2.waitKey(10) & 0xFF == ord("q"):
            break
            
    cap.release()
    cv2.destroyAllWindows()

# %%
# emergency exit command
cap.release()
cv2.destroyAllWindows()
